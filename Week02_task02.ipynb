# %% [markdown]
# <a href="https://colab.research.google.com/github/Malaika-05/AI-Training/blob/main/Week02_task02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TASK 1 — SMART SURVEILLANCE (IMAGE DATA)

# %%
import numpy as np
image = np.random.rand(224,224,3)
print(image.shape)
# Out:
# (224, 224, 3)

# %%
# Batch of 16 images
image_batch = np.random.rand(16,224,224,3)
print(image_batch.shape)
# Out:
# (16, 224, 224, 3)

# %% [markdown]
# # TASK 2 — VIDEO ACTIVITY RECOGNITION

# %%
video = np.random.rand(300,224,224,3)
print(video.shape)
# Out:
# (300, 224, 224, 3)

# %%
video_batch = np.random.rand(1,300,224,224,3)
print(video_batch.shape)
# Out:
# (1, 300, 224, 224, 3)

# %% [markdown]
# #TASK 3 — CUSTOMER CHURN RISK (PROBABILITY)

# %%
predictions = np.random.rand(20)
print(predictions)
# Out:
# [0.5350575  0.0054156  0.88312428 0.89463369 0.95504696 0.59281799
#  0.91469794 0.78146372 0.37516284 0.12422667 0.80255367 0.42238928
#  0.13978138 0.83117053 0.13148935 0.19347737 0.85278682 0.83872119
#  0.33265841 0.79760568]

# %%
high_risk = predictions[predictions>0.7]
print("High risk customer : ",len(high_risk))
# Out:
# High risk customer :  10

# %% [markdown]
# #TASK 4 — FEATURE CORRELATION (SALES DATA)

# %%
ads = [100, 200, 300, 400, 500]    # advertising budget
sales = [10, 20, 30, 40, 50]       # sales
corr_matrix = np.corrcoef(ads,sales)
print(corr_matrix)
# Out:
# [[1. 1.]
#  [1. 1.]]

# %% [markdown]
# #TASK 5 — MODEL LEARNING SIMULATION

# %%
w = 20
lr = 0.1

for i in range(10):
    loss = w**2
    w = w - lr * (2*w)
    print(f"Step {i}, Weight {w:.2f}, Loss {loss:.2f}")
# Out:
# Step 0, Weight 16.00, Loss 400.00
# Step 1, Weight 12.80, Loss 256.00
# Step 2, Weight 10.24, Loss 163.84
# Step 3, Weight 8.19, Loss 104.86
# Step 4, Weight 6.55, Loss 67.11
# Step 5, Weight 5.24, Loss 42.95
# Step 6, Weight 4.19, Loss 27.49
# Step 7, Weight 3.36, Loss 17.59
# Step 8, Weight 2.68, Loss 11.26
# Step 9, Weight 2.15, Loss 7.21

# %% [markdown]
# #TASK 6 — IMAGE vs VIDEO MEMORY COST

# %%
image01 = np.random.rand(224,224,3)
print("Image ",image01.shape)
# Out:
# Image  (224, 224, 3)

# %%
video01 = np.random.rand(30,224,224,3)
print("video ", video01.shape)
# Out:
# video  (30, 224, 224, 3)

# %%
print("Size of image ",image01.nbytes)
print("Size of video ",video01.nbytes)
# Out:
# Size of image  1204224
# Size of video  36126720

# %% [markdown]
# #TASK 7 — MINI BUSINESS DECISION

# %%
scores = np.random.rand(50)  # 50 transactions
print(scores[:10])
# Out:
# [0.80006207 0.19531124 0.62443812 0.27051851 0.54483224 0.15767219
#  0.68063989 0.17360186 0.12224784 0.10421043]

# %%
for t in [0.5, 0.7, 0.9]:
    alerts = len(scores[scores > t])
    print(f"Threshold {t}: {alerts} alerts")
# Out:
# Threshold 0.5: 22 alerts
# Threshold 0.7: 10 alerts
# Threshold 0.9: 3 alerts
